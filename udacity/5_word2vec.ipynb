# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = {}
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = []
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

# skip_window: window where to pick from (window lenght = 2 x skip_window + 1)
# num_skip: number of element to pick for each target
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  # Load element within the window in the buffer near data_index
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(): #, tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset) 
  print(embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup/Identity:0", shape=(128, 128), dtype=float32)
# WARNING:tensorflow:From /home/Luca/.conda/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1124: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.957465
# Nearest to use: northrop, vaikundar, overactive, vigorously, handicap, manuals, floor, championships,
# Nearest to other: cracow, hawthorne, masefield, expectations, melody, imperfect, exalted, ami,
# Nearest to will: variegated, audubon, reidel, muralitharan, daimyo, protester, sergeant, fgm,
# Nearest to up: almost, git, resurrect, mmu, mandrake, hx, wholly, relatedness,
# Nearest to years: preschool, modernizing, herakles, undesirable, cumont, musashi, montagu, meteor,
# Nearest to of: oahu, kmt, generous, khrushchev, zach, crisp, finder, openly,
# Nearest to these: suharto, verdict, ng, obscures, partnerships, introductory, bilabial, democracies,
# Nearest to people: traversing, combo, cytokinesis, transplantation, zheng, microorganisms, albion, meritocracy,
# Nearest to zero: restless, bugatti, kri, quality, retiring, acknowledgment, coaster, bessarabia,
# Nearest to was: accusative, clumsy, debate, scientific, feat, phantom, culloden, nerva,
# Nearest to over: vdash, determines, squandered, diane, local, ticker, mountaineers, humanist,
# Nearest to about: attends, foundations, desert, tiamat, xv, prince, journals, elegant,
# Nearest to it: newsreel, factorization, brasil, mithraea, abdur, rucker, maeterlinck, amorites,
# Nearest to he: bestselling, breakout, dewan, rigour, biscay, ladders, solzhenitsyn, pastry,
# Nearest to i: duly, rowboat, combating, dent, chilli, buoyancy, headings, photoelectric,
# Nearest to eight: lagrangian, inerrancy, scuderia, freedman, rpm, sunni, tamils, nerves,
# Average loss at step 2000: 4.365770
# Average loss at step 4000: 3.870285
# Average loss at step 6000: 3.789879
# Average loss at step 8000: 3.687355
# Average loss at step 10000: 3.616075
# Nearest to use: vigorously, northrop, stymied, prerecorded, aryabhata, overactive, handicap, development,
# Nearest to other: hawthorne, visa, condoned, cartridges, pot, browed, mages, indira,
# Nearest to will: would, audubon, variegated, saronic, northwestern, can, costanza, ara,
# Nearest to up: almost, git, lubricant, mandrake, mmu, hx, jj, ralston,
# Nearest to years: montagu, cumont, year, tyrannical, aargau, musashi, preschool, toward,
# Nearest to of: in, same, summands, ensured, infix, investments, from, for,
# Nearest to these: suharto, some, ng, travelled, partnerships, obscures, moncada, norah,
# Nearest to people: combo, spectrometry, zeal, asses, intercal, deprived, luxury, flowery,
# Nearest to zero: nine, eight, five, seven, three, six, four, two,
# Nearest to was: is, had, were, has, by, be, became, are,
# Nearest to over: local, squandered, humanist, favourably, leases, mink, drier, clitoris,
# Nearest to about: attends, desert, fatwas, sheds, beaten, rating, rammed, journals,
# Nearest to it: he, this, which, she, not, validating, there, who,
# Nearest to he: it, they, she, who, clausewitz, not, castilian, sometimes,
# Nearest to i: they, archtop, waller, millicent, websites, chains, coupled, lacked,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Average loss at step 12000: 3.603540
# Average loss at step 14000: 3.579053
# Average loss at step 16000: 3.411945
# Average loss at step 18000: 3.455991
# Average loss at step 20000: 3.544937
# Nearest to use: development, hellboy, gestalt, vigorously, mahdi, monies, stymied, prerecorded,
# Nearest to other: many, browed, some, musical, all, these, condoned, cartridges,
# Nearest to will: would, can, may, could, to, monic, might, orthogonality,
# Nearest to up: git, almost, lubricant, mandrake, minkowski, jj, mmu, hx,
# Nearest to years: year, predication, montagu, musashi, marbles, aquaria, aargau, inductively,
# Nearest to of: infix, summands, for, caches, same, original, egan, departure,
# Nearest to these: some, many, all, they, ng, bidder, suharto, such,
# Nearest to people: combo, spectrometry, quakers, rambouillet, inked, deprived, intercal, zeal,
# Nearest to zero: five, six, seven, eight, nine, three, four, two,
# Nearest to was: is, were, has, had, became, be, been, are,
# Nearest to over: drier, favourably, into, humanist, acharya, local, masturbate, through,
# Nearest to about: attends, sheds, fatwas, accelerates, birley, picked, flores, mast,
# Nearest to it: he, this, there, she, which, they, not, only,
# Nearest to he: it, she, they, who, there, leh, eventually, lemon,
# Nearest to i: they, ii, iii, millicent, agee, lacked, archtop, websites,
# Nearest to eight: seven, nine, six, four, five, three, two, zero,
# Average loss at step 22000: 3.503411
# Average loss at step 24000: 3.487155
# Average loss at step 26000: 3.480431
# Average loss at step 28000: 3.483955
# Average loss at step 30000: 3.504175
# Nearest to use: gestalt, northrop, vanities, districts, modify, dripping, mahdi, apogee,
# Nearest to other: browed, several, these, many, some, different, maturing, tudor,
# Nearest to will: would, can, may, could, must, might, to, should,
# Nearest to up: git, almost, minkowski, hx, vertov, him, pumped, hyperion,
# Nearest to years: year, days, predication, montagu, weeks, months, marbles, cumont,
# Nearest to of: in, summands, infix, including, anita, disloyal, mombasa, for,
# Nearest to these: some, many, all, they, such, those, both, several,
# Nearest to people: combo, polled, jews, cases, we, stupidity, men, years,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to was: is, had, has, were, been, became, when, foretold,
# Nearest to over: through, drier, automatic, mutinies, into, acharya, about, masturbate,
# Nearest to about: sheds, picked, fatwas, birley, macroeconomics, over, flores, corran,
# Nearest to it: he, there, this, she, they, not, which, what,
# Nearest to he: she, it, they, who, eventually, there, but, lemon,
# Nearest to i: they, you, we, ii, iii, g, archtop, nec,
# Nearest to eight: nine, seven, six, four, five, zero, three, two,
# Average loss at step 32000: 3.504196
# Average loss at step 34000: 3.496052
# Average loss at step 36000: 3.455882
# Average loss at step 38000: 3.301184
# Average loss at step 40000: 3.430048
# Nearest to use: districts, gestalt, duplicate, form, modify, mahdi, take, vanities,
# Nearest to other: different, various, abundant, maturing, strat, browed, operating, including,
# Nearest to will: would, can, may, could, must, might, should, cannot,
# Nearest to up: him, minkowski, back, out, them, vertov, git, menial,
# Nearest to years: days, months, year, weeks, predication, montagu, centuries, preschool,
# Nearest to of: in, infix, erwin, usual, for, original, from, including,
# Nearest to these: many, some, several, such, those, they, both, bidder,
# Nearest to people: men, sacks, polled, jews, stupidity, children, combo, asses,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to was: is, has, became, were, had, been, be, when,
# Nearest to over: automatic, masturbate, acharya, mutinies, through, about, drier, nearly,
# Nearest to about: birley, picked, flores, over, macroeconomics, fatwas, sheds, millennialism,
# Nearest to it: he, there, she, this, they, what, which, but,
# Nearest to he: she, it, they, who, there, i, eventually, griffiths,
# Nearest to i: we, you, they, he, ii, iii, sadistic, rearrangement,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Average loss at step 42000: 3.434382
# Average loss at step 44000: 3.454516
# Average loss at step 46000: 3.452518
# Average loss at step 48000: 3.358546
# Average loss at step 50000: 3.386237
# Nearest to use: form, gestalt, development, modify, paracelsus, adherence, patron, apogee,
# Nearest to other: different, abundant, various, milken, including, several, many, ernesto,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to up: them, out, back, down, vertov, minkowski, him, menial,
# Nearest to years: days, months, year, weeks, times, predication, centuries, pounds,
# Nearest to of: in, usual, and, infix, adenylate, caches, including, tap,
# Nearest to these: some, both, many, such, several, those, they, bidder,
# Nearest to people: men, jews, children, cases, years, someone, vizier, sacks,
# Nearest to zero: seven, eight, five, six, nine, four, three, two,
# Nearest to was: is, has, were, became, had, be, by, being,
# Nearest to over: through, into, automatic, masturbate, drier, mutinies, acharya, about,
# Nearest to about: birley, flores, over, picked, sheds, millennialism, anytime, macroeconomics,
# Nearest to it: he, she, there, this, they, still, temperament, often,
# Nearest to he: she, it, they, who, there, leh, brahman, soon,
# Nearest to i: you, ii, we, g, iii, they, t, he,
# Nearest to eight: seven, six, nine, four, five, three, zero, one,
# Average loss at step 52000: 3.440243
# Average loss at step 54000: 3.429795
# Average loss at step 56000: 3.439475
# Average loss at step 58000: 3.391617
# Average loss at step 60000: 3.394597
# Nearest to use: cause, form, paracelsus, duplicate, most, amount, gestalt, allow,
# Nearest to other: different, various, several, abundant, many, including, masefield, indira,
# Nearest to will: would, may, can, could, must, might, should, cannot,
# Nearest to up: down, out, them, back, minkowski, vertov, him, almost,
# Nearest to years: days, months, weeks, year, times, centuries, pounds, decades,
# Nearest to of: in, usual, for, dipping, infix, like, jervis, hasmonaean,
# Nearest to these: some, many, both, several, those, such, they, various,
# Nearest to people: men, children, polled, jews, others, westerners, someone, cases,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to was: is, had, became, has, were, been, began, although,
# Nearest to over: through, into, drier, about, throughout, masturbate, nearly, around,
# Nearest to about: birley, over, sheds, macroeconomics, flores, hala, corran, on,
# Nearest to it: he, she, there, this, they, still, now, what,
# Nearest to he: she, it, they, who, there, we, soon, kavina,
# Nearest to i: you, ii, we, g, they, iii, terrains, sadistic,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Average loss at step 62000: 3.242864
# Average loss at step 64000: 3.255407
# Average loss at step 66000: 3.404302
# Average loss at step 68000: 3.395431
# Average loss at step 70000: 3.360552
# Nearest to use: cause, allow, amount, form, most, primed, support, hellboy,
# Nearest to other: different, various, abundant, including, younger, milken, nitride, others,
# Nearest to will: would, may, can, must, could, might, should, cannot,
# Nearest to up: out, down, back, them, lubricant, minkowski, vertov, off,
# Nearest to years: days, months, weeks, year, decades, centuries, times, pounds,
# Nearest to of: including, in, for, and, infix, usual, syllabaries, original,
# Nearest to these: such, some, many, those, several, the, different, are,
# Nearest to people: men, children, polled, women, vizier, jews, neburg, chimes,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to was: is, has, were, had, when, became, been, being,
# Nearest to over: through, drier, about, into, masturbate, throughout, mutinies, within,
# Nearest to about: birley, over, macroeconomics, picked, sheds, on, anytime, flores,
# Nearest to it: he, she, there, this, they, itself, still, we,
# Nearest to he: she, it, they, there, who, we, eventually, soon,
# Nearest to i: ii, you, we, g, sadistic, they, gilmore, he,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Average loss at step 72000: 3.377773
# Average loss at step 74000: 3.348977
# Average loss at step 76000: 3.319636
# Average loss at step 78000: 3.354699
# Average loss at step 80000: 3.377715
# Nearest to use: form, modify, support, cause, amount, mahdi, because, duplicate,
# Nearest to other: various, including, younger, different, milken, abundant, neale, others,
# Nearest to will: would, may, can, could, must, might, should, cannot,
# Nearest to up: out, down, off, them, back, vertov, minkowski, him,
# Nearest to years: days, months, weeks, year, centuries, decades, times, hours,
# Nearest to of: including, original, in, bagoas, entire, piping, mobutu, usual,
# Nearest to these: several, many, those, both, such, some, various, definitions,
# Nearest to people: children, men, jews, women, polled, vizier, those, cases,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to was: is, were, became, has, had, being, be, been,
# Nearest to over: through, into, around, throughout, drier, masturbate, nearly, within,
# Nearest to about: birley, mohawk, explanations, anytime, days, hala, scrambling, fatwas,
# Nearest to it: he, she, there, this, they, we, not, still,
# Nearest to he: she, it, they, there, who, soon, we, leh,
# Nearest to i: g, you, ii, we, they, iii, sadistic, eluded,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Average loss at step 82000: 3.409919
# Average loss at step 84000: 3.410084
# Average loss at step 86000: 3.392815
# Average loss at step 88000: 3.352723
# Average loss at step 90000: 3.366931
# Nearest to use: modify, adherence, share, amount, cause, support, ulbricht, need,
# Nearest to other: various, different, younger, distinct, specific, milken, neale, maturing,
# Nearest to will: would, may, can, could, must, might, should, cannot,
# Nearest to up: out, down, off, back, them, him, lubricant, vertov,
# Nearest to years: days, months, weeks, year, centuries, decades, hours, times,
# Nearest to of: for, including, usual, in, analyse, suborders, disloyal, syllabaries,
# Nearest to these: several, many, some, various, are, those, such, definitions,
# Nearest to people: children, jews, men, women, polled, members, transcribe, christians,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to was: is, had, were, became, has, been, be, being,
# Nearest to over: through, into, around, masturbate, within, nearly, throughout, off,
# Nearest to about: birley, anytime, macroeconomics, unchallenged, bounce, archie, concerning, explanations,
# Nearest to it: he, she, there, this, they, itself, never, often,
# Nearest to he: she, it, they, there, who, soon, we, later,
# Nearest to i: g, you, ii, we, sadistic, iii, t, sediment,
# Nearest to eight: seven, six, nine, five, four, three, two, zero,
# Average loss at step 92000: 3.395799
# Average loss at step 94000: 3.251685
# Average loss at step 96000: 3.358308
# Average loss at step 98000: 3.245195
# Average loss at step 100000: 3.357205
# Nearest to use: adherence, amount, share, cause, form, modify, ulbricht, microcode,
# Nearest to other: various, younger, different, others, abundant, milken, subroutines, neale,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to up: out, off, back, down, him, them, minkowski, vertov,
# Nearest to years: days, months, year, weeks, decades, centuries, times, hours,
# Nearest to of: including, in, disloyal, original, suborders, and, infix, impassable,
# Nearest to these: several, many, some, various, those, all, were, different,
# Nearest to people: children, jews, men, women, those, polled, patients, persons,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to was: is, became, had, has, were, been, rifling, foretold,
# Nearest to over: through, within, into, nearly, drier, masturbate, cartel, showcasing,
# Nearest to about: birley, fatwas, anytime, delgado, macroeconomics, explanations, bounce, on,
# Nearest to it: he, she, this, there, they, nothing, what, often,
# Nearest to he: she, it, they, we, there, who, soon, never,
# Nearest to i: you, we, ii, they, g, sadistic, t, v,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,

# %%
num_points = 200

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

# skip_window: window where to pick from (window lenght = 2 x skip_window + 1)
# num_skip: number of element to pick for each target
def generate_batch_cbow(batch_size, context_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * context_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  # Load element within the window in the buffer near data_index
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i  in range(batch_size):
    context_value = []
    target = context_window  # target label at the center of the buffer
    for idx, val in enumerate(buffer): 
        if idx is not target:  
            context_value.append(val)
            
    batch[i] = context_value
    labels[i, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  return batch,labels

# data_index = 6781
# 
# batch, label  =generate_batch_cbow(128, 1)
# print('    batch:', [[reverse_dictionary[b] for b in bi] for bi in batch])
# print('    labels:', [reverse_dictionary[li] for li in labels.reshape(128)]) 


for context_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=10, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    print('    batch:', [[reverse_dictionary[b] for b in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(10)])
# Out:
# with context_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against'], ['used', 'early'], ['against', 'working']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early']
#
# with context_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working'], ['used', 'against', 'working', 'class'], ['against', 'early', 'class', 'radicals']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 1

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(): #, tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
  for idx in range(1, 2 * context_window): 
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:,idx])

    
#   embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
print(context_window)

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(batch_size, context_window)
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# 1
# Initialized
# Average loss at step 0: 7.478540
# Nearest to its: vanilla, karnataka, creditors, yttrium, lounge, lenition, recant, inexpensive,
# Nearest to are: respondent, steered, nebraska, opponents, seductive, fronting, possessive, garnering,
# Nearest to or: customized, centrality, bible, dissenters, scrolling, excerpts, bulge, ulrich,
# Nearest to used: lira, bureaucracies, genocides, highway, ornithologist, gog, calorie, danzig,
# Nearest to six: amitabh, iturbide, squadron, landmass, lc, dogmatic, honolulu, assassin,
# Nearest to would: tla, desert, carpathian, rod, mcg, prozac, lorraine, gehenna,
# Nearest to two: seconded, alternation, colonists, adapting, acapulco, ragnarok, bbc, gradual,
# Nearest to on: fledged, booty, manifestation, guardia, champion, virtualization, malik, combines,
# Nearest to b: hiragana, stoppage, refugees, decibel, sunday, truro, drpg, snake,
# Nearest to the: incumbent, steroid, corran, nightclub, done, abbreviated, spat, tone,
# Nearest to this: lar, homomorphisms, underway, hadith, shatz, counsels, ecu, asymmetry,
# Nearest to was: strassman, coercive, sneaking, kinetoscope, incunabula, originator, refuse, sulawesi,
# Nearest to other: motivation, consolidating, scorned, drachmae, nigh, nebuchadnezzar, minotaur, iww,
# Nearest to d: ann, bedroom, correlates, busby, laity, serbians, carbonated, iom,
# Nearest to when: mario, disappear, accesses, commits, henrik, premiers, clearances, koh,
# Nearest to in: reference, thenceforth, ovulation, broom, george, projectors, towns, homily,
# Average loss at step 2000: 4.103108
# Average loss at step 4000: 3.561855
# Average loss at step 6000: 3.390773
# Average loss at step 8000: 3.245994
# Average loss at step 10000: 3.175124
# Nearest to its: their, his, the, our, kenyan, tableland, childs, her,
# Nearest to are: were, is, have, mumia, mimosa, kant, been, sigmund,
# Nearest to or: and, than, tetrahedra, confessors, mindaugas, mixing, cours, coprocessor,
# Nearest to used: known, mostly, isomerism, javan, glissando, generally, petrograd, dih,
# Nearest to six: eight, nine, seven, five, three, four, zero, two,
# Nearest to would: can, could, will, may, did, might, must, to,
# Nearest to two: three, four, eight, six, seven, five, nine, one,
# Nearest to on: in, within, during, monkey, trios, under, at, for,
# Nearest to b: d, shiloh, sculptured, selamat, raf, refuting, clipper, meteorologists,
# Nearest to the: its, his, their, ennius, lye, fraktion, this, theorised,
# Nearest to this: it, which, amstrad, that, the, abbreviating, oncology, eac,
# Nearest to was: is, were, had, has, be, noor, frick, became,
# Nearest to other: many, obstruct, consolidating, addressing, sponsorship, forehead, maori, fugal,
# Nearest to d: b, aonb, shiloh, sorcerers, correlates, circulation, alexanderplatz, carp,
# Nearest to when: koh, commits, where, if, q, walla, nero, nanaimo,
# Nearest to in: at, on, during, under, from, with, shelved, monogamy,
# Average loss at step 12000: 3.200840
# Average loss at step 14000: 3.152008
# Average loss at step 16000: 3.181121
# Average loss at step 18000: 3.124322
# Average loss at step 20000: 2.992553
# Nearest to its: their, his, her, the, our, childs, your, neverwinter,
# Nearest to are: were, have, is, be, inquisition, mumia, been, compensating,
# Nearest to or: and, than, stereotypically, banyan, impetus, grimaldi, internationals, hasan,
# Nearest to used: known, called, represented, seen, written, mostly, considered, encouraged,
# Nearest to six: five, eight, seven, nine, four, three, zero, two,
# Nearest to would: could, will, can, may, might, must, should, did,
# Nearest to two: three, four, seven, six, one, five, eight, nine,
# Nearest to on: upon, in, at, during, hess, monkey, subdue, sdk,
# Nearest to b: d, hostages, aelia, bioterrorism, selamat, denominator, aegon, molinari,
# Nearest to the: a, his, their, its, any, this, another, iceni,
# Nearest to this: which, it, that, amstrad, what, the, some, any,
# Nearest to was: is, has, were, had, became, did, waas, noor,
# Nearest to other: different, forehead, obstruct, impromptu, quod, consolidating, comical, many,
# Nearest to d: b, correlates, statically, ann, maths, mahagonny, sorcerers, monotone,
# Nearest to when: if, before, where, with, xix, after, but, cruisers,
# Nearest to in: at, negated, during, coloane, on, gal, of, carat,
# Average loss at step 22000: 3.074243
# Average loss at step 24000: 3.036104
# Average loss at step 26000: 3.004822
# Average loss at step 28000: 3.025294
# Average loss at step 30000: 3.008014
# Nearest to its: their, his, her, our, the, your, childs, toba,
# Nearest to are: were, is, have, include, mimosa, relatedness, unofficially, typhoon,
# Nearest to or: and, than, nilo, stereotypically, inflate, giraffe, duesberg, feather,
# Nearest to used: known, published, seen, called, considered, written, given, described,
# Nearest to six: four, seven, nine, eight, five, three, two, zero,
# Nearest to would: will, could, may, can, might, must, should, did,
# Nearest to two: three, six, five, four, seven, nine, eight, one,
# Nearest to on: upon, under, through, in, at, around, demographic, goshen,
# Nearest to b: d, dicaprio, checkpoints, creates, uneventful, denominator, inventive, nomen,
# Nearest to the: their, its, ennius, this, our, childs, a, tze,
# Nearest to this: which, it, amstrad, that, the, boundless, what, accelerators,
# Nearest to was: is, has, became, had, were, be, did, been,
# Nearest to other: different, forehead, obstruct, various, quod, many, smaller, impromptu,
# Nearest to d: b, sebastian, mahagonny, ann, correlates, maths, aonb, kenning,
# Nearest to when: if, before, after, where, while, although, though, xix,
# Nearest to in: during, within, at, from, on, recoup, electromagnetic, rodr,
# Average loss at step 32000: 2.825514
# Average loss at step 34000: 2.958552
# Average loss at step 36000: 2.949484
# Average loss at step 38000: 2.941344
# Average loss at step 40000: 2.931250
# Nearest to its: their, his, the, her, your, our, childs, swear,
# Nearest to are: were, is, have, include, be, mumia, been, sigmund,
# Nearest to or: and, than, whose, mixing, duesberg, cours, while, but,
# Nearest to used: known, written, seen, described, considered, published, referred, represented,
# Nearest to six: five, eight, four, seven, three, nine, two, zero,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to two: three, six, five, four, seven, eight, nine, one,
# Nearest to on: upon, during, through, around, under, within, septuagint, monkey,
# Nearest to b: d, aegon, nomen, adel, redemption, r, nupedia, uneventful,
# Nearest to the: its, their, a, his, childs, your, any, yaw,
# Nearest to this: which, it, gutenberg, exertion, what, amd, endowments, shiny,
# Nearest to was: is, became, had, were, has, noor, seems, becomes,
# Nearest to other: obstruct, various, forehead, different, many, smaller, rajput, rather,
# Nearest to d: b, sebastian, mahagonny, geckos, ann, piedmont, tutorial, h,
# Nearest to when: if, before, after, where, while, during, although, though,
# Nearest to in: during, within, among, tutored, throughout, through, rodr, anthropic,
# Average loss at step 42000: 2.949966
# Average loss at step 44000: 2.956316
# Average loss at step 46000: 2.903921
# Average loss at step 48000: 2.870078
# Average loss at step 50000: 2.850597
# Nearest to its: their, his, our, her, your, the, whose, childs,
# Nearest to are: were, have, is, include, be, merchant, including, sigmund,
# Nearest to or: and, than, but, feather, muscat, rube, majored, laconic,
# Nearest to used: known, described, seen, referred, written, considered, published, defined,
# Nearest to six: seven, eight, four, nine, five, three, two, zero,
# Nearest to would: could, will, may, might, can, should, must, did,
# Nearest to two: three, four, six, seven, eight, five, nine, one,
# Nearest to on: upon, in, under, within, through, during, about, around,
# Nearest to b: d, subiaco, shiloh, maths, kaluza, checkpoints, refuting, herndon,
# Nearest to the: their, its, a, tze, any, mapsto, your, each,
# Nearest to this: which, it, itself, what, another, that, exertion, amstrad,
# Nearest to was: is, became, had, were, has, becomes, noor, been,
# Nearest to other: obstruct, different, various, others, forehead, smaller, cognitive, rather,
# Nearest to d: b, correlates, masturbate, ann, auditing, zondervan, wade, staples,
# Nearest to when: if, after, where, before, while, terraced, during, though,
# Nearest to in: within, during, at, on, of, throughout, from, astro,
# Average loss at step 52000: 2.883113
# Average loss at step 54000: 2.858978
# Average loss at step 56000: 2.854639
# Average loss at step 58000: 2.751794
# Average loss at step 60000: 2.829773
# Nearest to its: their, his, her, our, your, whose, the, swear,
# Nearest to are: were, is, have, include, including, be, substantive, while,
# Nearest to or: and, than, though, batasuna, apparitions, rube, giraffe, repeaters,
# Nearest to used: known, seen, described, considered, defined, referred, found, written,
# Nearest to six: five, seven, eight, four, nine, three, two, zero,
# Nearest to would: will, could, can, might, should, must, may, cannot,
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to on: upon, through, under, within, at, during, in, around,
# Nearest to b: d, subiaco, c, ting, necessitate, adel, hostages, necropolis,
# Nearest to the: their, this, his, its, any, our, another, a,
# Nearest to this: it, which, the, what, another, some, any, each,
# Nearest to was: is, had, has, became, were, noor, did, be,
# Nearest to other: various, cognitive, others, obstruct, individual, older, different, forehead,
# Nearest to d: b, maths, ann, sebastian, staples, wade, correlates, countercultural,
# Nearest to when: if, where, before, after, during, while, terraced, though,
# Nearest to in: during, within, among, at, on, negated, under, through,
# Average loss at step 62000: 2.829939
# Average loss at step 64000: 2.775824
# Average loss at step 66000: 2.761167
# Average loss at step 68000: 2.711515
# Average loss at step 70000: 2.778436
# Nearest to its: their, the, his, whose, our, her, your, structural,
# Nearest to are: were, include, is, have, those, including, substantive, be,
# Nearest to or: and, than, majored, maulana, induced, giraffe, salim, nor,
# Nearest to used: known, seen, described, referred, considered, available, found, defined,
# Nearest to six: seven, five, eight, nine, four, three, zero, two,
# Nearest to would: could, will, might, may, should, can, must, did,
# Nearest to two: three, four, six, seven, five, eight, one, nine,
# Nearest to on: upon, in, through, within, under, around, at, against,
# Nearest to b: d, subiaco, kaluza, ocaml, sousa, shiloh, brewed, ting,
# Nearest to the: its, their, a, his, any, this, mapsto, our,
# Nearest to this: which, it, what, some, each, the, traversing, another,
# Nearest to was: is, had, has, became, were, been, noor, seems,
# Nearest to other: various, cognitive, individual, forehead, obstruct, different, smaller, condense,
# Nearest to d: b, maths, kenning, wade, yevgeny, staples, ann, auditing,
# Nearest to when: if, before, while, after, during, though, although, where,
# Nearest to in: within, during, under, on, at, throughout, of, since,
# Average loss at step 72000: 2.798732
# Average loss at step 74000: 2.649162
# Average loss at step 76000: 2.806671
# Average loss at step 78000: 2.821544
# Average loss at step 80000: 2.779300
# Nearest to its: their, his, whose, her, the, structural, our, your,
# Nearest to are: were, have, is, include, exist, be, those, merchant,
# Nearest to or: and, though, than, nor, guadalupe, majored, apparitions, strumming,
# Nearest to used: known, referred, seen, considered, described, available, defined, applied,
# Nearest to six: eight, seven, five, nine, four, three, zero, two,
# Nearest to would: could, will, might, can, should, must, may, cannot,
# Nearest to two: three, four, five, seven, six, eight, one, nine,
# Nearest to on: upon, in, during, within, centriole, around, through, against,
# Nearest to b: d, p, c, subiaco, ting, ocaml, cdot, meteorologists,
# Nearest to the: their, its, his, our, a, ortelius, your, each,
# Nearest to this: which, it, another, what, that, some, similar, each,
# Nearest to was: is, has, had, became, were, becomes, remained, been,
# Nearest to other: various, cognitive, individual, obstruct, most, others, protege, endangered,
# Nearest to d: b, nd, maths, kenning, c, ann, auditing, yevgeny,
# Nearest to when: before, after, if, while, during, although, though, where,
# Nearest to in: during, within, near, at, under, on, among, throughout,
# Average loss at step 82000: 2.667313
# Average loss at step 84000: 2.770251
# Average loss at step 86000: 2.739042
# Average loss at step 88000: 2.752258
# Average loss at step 90000: 2.738730
# Nearest to its: their, whose, his, the, our, her, structural, hayao,
# Nearest to are: were, is, have, include, including, carradine, exist, merchant,
# Nearest to or: and, though, than, majored, while, although, nor, barbed,
# Nearest to used: known, seen, referred, described, applied, represented, found, called,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to would: could, will, might, should, can, must, may, cannot,
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to on: upon, in, through, concerning, within, at, about, near,
# Nearest to b: d, f, c, subiaco, p, hippolyte, hostages, ting,
# Nearest to the: its, his, our, their, childs, your, this, whose,
# Nearest to this: which, it, what, each, accelerators, the, another, that,
# Nearest to was: is, has, became, had, becomes, were, seems, remained,
# Nearest to other: various, cognitive, individual, others, obstruct, endangered, different, several,
# Nearest to d: b, maths, kenning, dizzy, nd, j, ann, yevgeny,
# Nearest to when: if, while, before, although, after, where, though, terraced,
# Nearest to in: within, during, on, near, through, throughout, at, from,
# Average loss at step 92000: 2.682714
# Average loss at step 94000: 2.717999
# Average loss at step 96000: 2.705512
# Average loss at step 98000: 2.365200
# Average loss at step 100000: 2.401654
# Nearest to its: their, his, whose, her, our, the, your, ym,
# Nearest to are: were, have, include, contain, is, involve, exist, those,
# Nearest to or: and, nor, than, though, salim, lo, maulana, vs,
# Nearest to used: known, seen, referred, described, required, applied, found, performed,
# Nearest to six: eight, seven, nine, five, four, three, zero, two,
# Nearest to would: could, will, might, can, should, must, may, cannot,
# Nearest to two: five, four, three, eight, six, seven, nine, zero,
# Nearest to on: upon, through, within, at, in, oratio, near, exilic,
# Nearest to b: d, mantis, subiaco, rickenbacker, kaluza, dragonball, nu, checkpoints,
# Nearest to the: their, his, our, its, her, your, this, childs,
# Nearest to this: which, what, each, it, another, some, adventist, the,
# Nearest to was: is, had, became, has, were, remains, seems, does,
# Nearest to other: various, individual, others, cognitive, obstruct, different, forehead, quod,
# Nearest to d: b, yevgeny, kenning, mahagonny, maths, twitching, shiloh, wade,
# Nearest to when: if, while, after, before, where, during, though, although,
# Nearest to in: within, during, near, at, negated, coquitlam, of, among,

# %%
num_points = 200

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
