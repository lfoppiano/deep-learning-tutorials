# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = {}
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = []
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

# skip_window: window where to pick from (window lenght = 2 x skip_window + 1)
# num_skip: number of element to pick for each target
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  # Load element within the window in the buffer near data_index
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(): #, tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset) 
  print(embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup/Identity:0", shape=(128, 128), dtype=float32)
# WARNING:tensorflow:From /anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1124: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.161936
# Nearest to its: marianas, indy, dweller, apis, venerable, examining, intifada, amniotic,
# Nearest to first: bevan, serial, puppet, unconventional, lettuce, musicbrainz, banning, lakers,
# Nearest to th: dormancy, hammerstein, united, aorta, cert, hoarding, gated, choirs,
# Nearest to had: glycogen, angiotensin, outmoded, dismemberment, acf, hindus, hasn, bijapur,
# Nearest to american: lsch, hospitals, conveyor, rafter, zoster, magnetite, meo, carr,
# Nearest to can: deified, reduce, michelangelo, californium, taipa, sahelian, extracting, commemoration,
# Nearest to nine: foul, gynt, consolidate, romany, atkinson, multicellular, newsweek, mediocre,
# Nearest to new: df, thin, wardrobe, removal, increases, arena, instantaneous, sidelined,
# Nearest to eight: slabs, neurotoxicity, silo, feats, celebratory, avenger, h, gianfranco,
# Nearest to other: bans, deccan, darrow, sympathizer, este, eli, hiding, jeffreys,
# Nearest to time: troubling, modernity, completion, suppressed, kidding, timberlake, allergies, monegasque,
# Nearest to have: devised, hosted, resistant, serfs, consuming, change, rumford, cordillera,
# Nearest to many: heart, delphi, correlatives, dispersion, rating, hiding, washington, shtml,
# Nearest to four: glass, less, joliet, satiric, elsinore, supposes, telecoms, acquaintances,
# Nearest to would: acknowledged, mohenjo, pavilion, drying, areas, lawlessness, pidgin, anecdotal,
# Nearest to for: blueprint, cira, hesitate, way, elihu, demilitarized, trappings, oscar,
# Average loss at step 2000: 4.366158
# Average loss at step 4000: 3.858184
# Average loss at step 6000: 3.792171
# Average loss at step 8000: 3.680247
# Average loss at step 10000: 3.614979
# Nearest to its: the, their, mined, his, jungles, venerable, microscope, holly,
# Nearest to first: last, andamanese, musicbrainz, lakers, second, term, deity, overridden,
# Nearest to th: dormancy, three, hoarding, roleplay, four, starve, seven, bernardo,
# Nearest to had: have, has, was, acf, were, taya, uncollected, meitner,
# Nearest to american: hospitals, chromium, magnetite, teenager, rafter, icbms, ballard, conveyor,
# Nearest to can: may, would, consulted, could, might, antiquark, coastal, minimizes,
# Nearest to nine: eight, six, seven, zero, five, four, three, two,
# Nearest to new: arena, sidelined, increases, cosmology, obscura, df, multinational, removal,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to other: many, eli, draw, different, bans, impeach, eagles, rapcore,
# Nearest to time: brilliant, completion, bitterness, dharma, knossos, applause, latch, publication,
# Nearest to have: had, has, be, hexen, were, are, heaped, warns,
# Nearest to many: some, dispersion, other, lipoprotein, all, correlatives, chalcedon, stretch,
# Nearest to four: six, three, eight, seven, five, two, nine, zero,
# Nearest to would: can, may, will, could, might, raping, acknowledged, drying,
# Nearest to for: after, within, pharaonic, communicative, of, mexican, financial, blueprint,
# Average loss at step 12000: 3.602719
# Average loss at step 14000: 3.569551
# Average loss at step 16000: 3.412819
# Average loss at step 18000: 3.455880
# Average loss at step 20000: 3.545153
# Nearest to its: their, his, the, mined, any, microscope, her, evolution,
# Nearest to first: last, second, musicbrainz, following, andamanese, wandered, abm, term,
# Nearest to th: dormancy, starve, hoarding, roleplay, rd, bestseller, mosaic, nd,
# Nearest to had: has, have, was, were, having, davao, plays, acf,
# Nearest to american: hospitals, russian, chromium, teenager, australian, scat, english, canadian,
# Nearest to can: may, would, could, will, might, should, consulted, must,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to new: arena, increases, cosmology, removal, sidelined, wardrobe, sahib, storm,
# Nearest to eight: nine, seven, six, five, four, three, two, zero,
# Nearest to other: many, different, some, burali, eli, impeach, those, are,
# Nearest to time: year, brilliant, royalists, dharma, fiske, cycling, completion, insights,
# Nearest to have: had, has, be, were, are, having, transjordan, hexen,
# Nearest to many: some, several, other, all, these, enclave, lipoprotein, most,
# Nearest to four: six, seven, five, eight, three, two, nine, zero,
# Nearest to would: will, may, could, can, might, should, must, raping,
# Nearest to for: by, with, communicative, of, at, keeps, in, and,
# Average loss at step 22000: 3.500824
# Average loss at step 24000: 3.489883
# Average loss at step 26000: 3.481496
# Average loss at step 28000: 3.480171
# Average loss at step 30000: 3.502511
# Nearest to its: their, the, his, mined, her, kashubians, water, foodstuffs,
# Nearest to first: last, second, musicbrainz, westeros, when, same, original, wandered,
# Nearest to th: rd, starve, nd, seven, hoarding, dormancy, eight, sympathizers,
# Nearest to had: has, have, was, were, having, detonated, would, been,
# Nearest to american: english, australian, british, canadian, german, steady, magnetite, hospitals,
# Nearest to can: may, would, could, will, might, should, must, cannot,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to new: arena, sahib, removal, playlist, cosmology, anglican, increases, bangladesh,
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to other: burali, different, various, those, many, these, their, notable,
# Nearest to time: year, issue, breakup, fiske, dharma, brilliant, royalists, arian,
# Nearest to have: had, has, were, are, be, having, occupy, grids,
# Nearest to many: some, several, these, all, enclave, most, the, those,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to would: can, could, will, may, might, must, should, to,
# Nearest to for: after, keeps, communicative, stardom, mexican, against, financial, when,
# Average loss at step 32000: 3.500593
# Average loss at step 34000: 3.493381
# Average loss at step 36000: 3.457156
# Average loss at step 38000: 3.298853
# Average loss at step 40000: 3.426298
# Nearest to its: their, his, her, the, mined, any, water, loans,
# Nearest to first: second, last, musicbrainz, next, westeros, spacecraft, mid, napster,
# Nearest to th: five, nd, rd, three, hoarding, starve, seven, bestseller,
# Nearest to had: has, have, was, having, were, would, heaped, plays,
# Nearest to american: australian, british, canadian, english, german, magnetite, french, russian,
# Nearest to can: may, will, could, would, might, should, must, cannot,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to new: arena, sahib, expects, brabant, removal, anglican, bangladesh, playlist,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to other: different, various, burali, those, many, these, berries, rapcore,
# Nearest to time: year, dharma, cdg, belief, arian, issue, remaining, way,
# Nearest to have: had, has, were, are, be, having, already, camille,
# Nearest to many: some, several, these, those, various, all, both, most,
# Nearest to four: six, three, two, seven, five, eight, nine, one,
# Nearest to would: can, could, will, may, might, must, should, cannot,
# Nearest to for: in, by, of, within, mexican, keeps, connexion, on,
# Average loss at step 42000: 3.430656
# Average loss at step 44000: 3.452055
# Average loss at step 46000: 3.451865
# Average loss at step 48000: 3.349721
# Average loss at step 50000: 3.379732
# Nearest to its: their, his, the, mined, her, my, automate, waxes,
# Nearest to first: last, second, next, mid, musicbrainz, best, uprising, spacecraft,
# Nearest to th: five, rd, nd, bestseller, starve, hoarding, six, richter,
# Nearest to had: has, have, was, having, were, since, heaped, plays,
# Nearest to american: english, french, australian, canadian, international, british, german, magnetite,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to nine: eight, seven, six, four, three, five, two, zero,
# Nearest to new: sahib, expects, anglican, arena, removal, obeys, mistakenly, brabant,
# Nearest to eight: six, nine, seven, five, four, three, two, one,
# Nearest to other: different, various, some, burali, including, many, these, local,
# Nearest to time: royalists, year, remaining, way, arian, trusting, aortic, half,
# Nearest to have: had, has, were, are, be, already, having, passant,
# Nearest to many: some, several, these, various, both, those, most, working,
# Nearest to four: six, three, five, eight, seven, nine, two, zero,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to for: while, against, on, connexion, delved, using, after, within,
# Average loss at step 52000: 3.440153
# Average loss at step 54000: 3.428100
# Average loss at step 56000: 3.438547
# Average loss at step 58000: 3.395440
# Average loss at step 60000: 3.389787
# Nearest to its: their, his, the, her, mined, waxes, my, pollination,
# Nearest to first: last, second, next, same, spacecraft, best, original, musicbrainz,
# Nearest to th: nd, five, eight, six, rd, four, bestseller, starve,
# Nearest to had: has, have, was, having, were, plays, saw, although,
# Nearest to american: english, british, international, annotated, canadian, german, french, australian,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to new: arena, kernels, regarding, brabant, particular, sahib, tnt, anglican,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to other: different, various, many, some, including, burali, those, these,
# Nearest to time: arian, royalists, way, year, aortic, trusting, dharma, level,
# Nearest to have: had, has, are, were, be, having, include, grids,
# Nearest to many: some, several, various, these, those, both, numerous, most,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to for: of, if, communicative, including, using, against, when, pharaonic,
# Average loss at step 62000: 3.244152
# Average loss at step 64000: 3.253134
# Average loss at step 66000: 3.410350
# Average loss at step 68000: 3.394874
# Average loss at step 70000: 3.360239
# Nearest to its: their, his, the, her, our, my, loans, whose,
# Nearest to first: second, last, next, best, original, third, same, during,
# Nearest to th: nd, rd, seven, bestseller, six, eight, starve, inmate,
# Nearest to had: has, have, was, having, were, yarn, been, saw,
# Nearest to american: british, english, international, canadian, annotated, actors, sporting, french,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to new: removal, regarding, arena, kernels, brabant, delle, bangladesh, obscura,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to other: different, various, including, some, petitions, burali, many, rapcore,
# Nearest to time: year, trusting, arian, royalists, dharma, bikram, quicker, way,
# Nearest to have: had, has, were, are, be, having, resemble, include,
# Nearest to many: some, several, various, these, most, both, those, all,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to would: will, can, could, may, might, should, must, cannot,
# Nearest to for: in, using, to, while, pharaonic, after, communicative, against,
# Average loss at step 72000: 3.376772
# Average loss at step 74000: 3.346709
# Average loss at step 76000: 3.321081
# Average loss at step 78000: 3.353958
# Average loss at step 80000: 3.377387
# Nearest to its: their, his, her, the, our, my, your, loans,
# Nearest to first: second, last, next, third, same, fourth, original, best,
# Nearest to th: nd, rd, six, five, bestseller, bc, tornadoes, karabiners,
# Nearest to had: have, has, were, having, was, saw, been, plays,
# Nearest to american: british, canadian, english, annotated, german, international, irish, french,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to new: tnt, brabant, arena, single, kernels, dotted, arras, removal,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to other: various, different, burali, including, disconcerting, border, some, berries,
# Nearest to time: year, arian, dharma, royalists, belief, trusting, breakup, bikram,
# Nearest to have: had, has, were, are, having, be, reflect, represent,
# Nearest to many: some, several, various, these, numerous, those, most, both,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to for: injuring, lobby, against, communicative, russo, malibu, while, connexion,
# Average loss at step 82000: 3.406127
# Average loss at step 84000: 3.409547
# Average loss at step 86000: 3.389403
# Average loss at step 88000: 3.353054
# Average loss at step 90000: 3.367730
# Nearest to its: their, his, her, the, our, my, your, whose,
# Nearest to first: last, second, original, next, best, largest, spacecraft, same,
# Nearest to th: rd, nd, seven, eight, nine, four, one, bestseller,
# Nearest to had: has, have, was, were, having, numerology, mustafa, been,
# Nearest to american: british, english, canadian, french, german, irish, italian, repairs,
# Nearest to can: may, could, will, might, must, should, would, cannot,
# Nearest to nine: seven, eight, six, five, four, three, zero, two,
# Nearest to new: arena, different, sarti, particular, kernels, single, tnt, separate,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to other: various, different, including, burali, liability, jair, individual, remotely,
# Nearest to time: year, arian, royalists, dharma, bikram, reason, clade, trusting,
# Nearest to have: had, has, were, be, having, are, resemble, require,
# Nearest to many: some, several, numerous, various, these, most, all, those,
# Nearest to four: seven, five, eight, six, three, two, nine, one,
# Nearest to would: will, could, might, can, may, should, must, cannot,
# Nearest to for: against, including, of, while, communicative, concerning, tremendous, injuring,
# Average loss at step 92000: 3.399319
# Average loss at step 94000: 3.250942
# Average loss at step 96000: 3.356249
# Average loss at step 98000: 3.242738
# Average loss at step 100000: 3.357193
# Nearest to its: their, his, the, her, our, your, whose, loans,
# Nearest to first: last, second, next, third, fourth, original, best, spacecraft,
# Nearest to th: rd, nd, fifth, st, starve, fourth, third, reeve,
# Nearest to had: has, have, was, having, were, mustafa, since, plays,
# Nearest to american: british, canadian, australian, italian, french, hearse, german, cooperative,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to new: single, different, tnt, arena, separate, brabant, obscura, expects,
# Nearest to eight: seven, nine, six, four, five, three, two, zero,
# Nearest to other: various, others, different, burali, including, individual, rapcore, vojvodina,
# Nearest to time: year, royalists, brilliant, way, completion, future, arian, reason,
# Nearest to have: had, has, were, are, require, having, include, resemble,
# Nearest to many: several, some, these, various, numerous, those, all, few,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to would: will, could, can, might, should, may, must, cannot,
# Nearest to for: against, including, pharaonic, despite, after, when, before, although,

# %%
num_points = 200

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

# skip_window: window where to pick from (window lenght = 2 x skip_window + 1)
def generate_batch_cbow(batch_size, context_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * context_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  # Load element within the window in the buffer near data_index
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i  in range(batch_size):
    context_value = []
    target = context_window  # target label at the center of the buffer
    for idx, val in enumerate(buffer): 
        if idx is not target:  
            context_value.append(val)
            
    batch[i] = context_value
    labels[i, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  return batch,labels

# data_index = 6781
# 
# batch, label  =generate_batch_cbow(128, 1)
# print('    batch:', [[reverse_dictionary[b] for b in bi] for bi in batch])
# print('    labels:', [reverse_dictionary[li] for li in labels.reshape(128)]) 

print('data:', [reverse_dictionary[di] for di in data[:8]])

for context_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=10, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    print('    batch:', [[reverse_dictionary[b] for b in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(10)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with context_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against'], ['used', 'early'], ['against', 'working']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early']
#
# with context_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working'], ['used', 'against', 'working', 'class'], ['against', 'early', 'class', 'radicals']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 2

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(): #, tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # I forgot this part
  embed = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
#   for idx in range(1, 2 * context_window): 
#     embed += tf.nn.embedding_lookup(embeddings, train_dataset[:,idx])

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(batch_size, context_window)
    
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 9.106613
# Nearest to history: dictating, plantation, trustedbsd, tau, forcibly, arnaud, nayla, entrant,
# Nearest to th: locals, torn, sunflower, adjustments, engineer, pictures, oro, highlands,
# Nearest to have: decoys, children, irregularity, hexagrams, anatoly, brightly, judge, participle,
# Nearest to first: abolish, vyacheslav, scavenging, uncensored, kickboxing, ferranti, uranhay, juggalo,
# Nearest to than: brahms, peerage, hoplites, stroke, aerosols, consilience, neuronal, browne,
# Nearest to years: insurer, separators, girlfriend, sited, egon, masse, nissan, afflicted,
# Nearest to people: colspan, torches, irresponsible, semblance, paddling, reagent, sight, dari,
# Nearest to b: claude, trendy, upgrading, regicide, reaffirmed, immature, wires, elagabalus,
# Nearest to in: wb, cervical, pagerank, mammuthus, pronouns, postulated, loveland, dylan,
# Nearest to into: admin, strikes, bacall, tumors, redefined, kestrel, censoring, collections,
# Nearest to its: skull, damasus, crist, departs, earls, nei, psychical, canal,
# Nearest to most: cliffordadams, model, francophonie, sitcom, cleartype, buy, kemal, gagarin,
# Nearest to such: inverting, bahasa, clunies, whistle, platypus, francorum, alleviated, viaduct,
# Nearest to he: virginal, tabloid, questioner, ffg, relax, masai, saxony, chanting,
# Nearest to if: marino, chileans, leptons, rpr, mychal, kahanamoku, adagio, homosexuality,
# Nearest to war: aromatic, finite, anthrax, lampoon, insular, catapults, triadic, insurmountable,
# Average loss at step 2000: 4.427663
# Average loss at step 4000: 3.847256
# Average loss at step 6000: 3.739326
# Average loss at step 8000: 3.679109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-af69ce96b763> in <module>
#       9
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12     average_loss += l
#      13     if step % 2000 == 0:
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_points = 200

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
